# %% [markdown]
# # Import all needed packages

# %%
import boto3
import json

# %% [markdown]
# # Setup the Bedrock runtime

# %%
bedrock_runtime = boto3.client('bedrock-runtime', region_name='us-west-2')

# %%
prompt = "Write a one sentence summary of Learning."

# %%
print(prompt)
# Out:
# Write a one sentence summary of Learning.

# %%
kwargs = {
    "modelId": "amazon.titan-text-lite-v1",
    "contentType": "application/json",
    "accept": "*/*",
    "body": json.dumps(
        {
            "inputText": prompt
        }
    )
}

# %%
response = bedrock_runtime.invoke_model(**kwargs)

# %%
print(response)
# Out:
# {'ResponseMetadata': {'RequestId': '047053d1-3b1e-4528-9eff-fdd53b2a45a9', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 01 Sep 2024 19:14:39 GMT', 'content-type': 'application/json', 'content-length': '203', 'connection': 'keep-alive', 'x-amzn-requestid': '047053d1-3b1e-4528-9eff-fdd53b2a45a9', 'x-amzn-bedrock-invocation-latency': '868', 'x-amzn-bedrock-output-token-count': '19', 'x-amzn-bedrock-input-token-count': '8'}, 'RetryAttempts': 0}, 'contentType': 'application/json', 'body': <botocore.response.StreamingBody object at 0x11190f310>}

# %%
response_body = json.loads(response.get('body').read())

# %%
print(json.dumps(response_body, indent=4))
# Out:
# {
#     "inputTextTokenCount": 8,
#     "results": [
#         {
#             "tokenCount": 19,
#             "outputText": "\nLearning is a process of acquiring knowledge and skills through experience, observation, and practice.",
#             "completionReason": "FINISH"
#         }
#     ]
# }

# %%
print(response_body['results'][0]['outputText'])
# Out:
# Learning is a process of acquiring knowledge and skills through experience, observation, and practice.

# %% [markdown]
# # Generation Configuration

# %%
prompt = "Write a summary of India."

# %%
kwargs = {
    "modelId": "amazon.titan-text-express-v1",
    "contentType": "application/json",
    "accept": "*/*",
    "body" : json.dumps(
        {
            "inputText": prompt,
            "textGenerationConfig": {
                "maxTokenCount": 100,
                "temperature": 0.7,
                "topP": 0.9
            }
        }
    )
}

# %%
response = bedrock_runtime.invoke_model(**kwargs)
response_body = json.loads(response.get('body').read())

generation = response_body['results'][0]['outputText']
print(generation)
# Out:
# India is a country in South Asia officially known as the Republic of India. It is a country in South Asia formally known as the Republic of India. It is a country governed by a constitutional democracy and is one of the world's fastest-growing economies. India has a diverse culture that reflects its long history and many regional traditions. It is the seventh-largest country in the world by area and has a population of over 1.3 billion people, making it the second-most populous

# %%
print(json.dumps(response_body, indent=4))
# Out:
# {
#     "inputTextTokenCount": 6,
#     "results": [
#         {
#             "tokenCount": 100,
#             "outputText": "\nIndia is a country located in South Asia, which is the seventh-largest country in the world. It is the second-most populous country in the world, with over 1.3 billion people, and the seventh-largest country in the world by area, with over 3.2 million square kilometers. India is known for its diverse culture, rich history, and natural beauty.\n\nIndia has a rich and diverse history that dates back to ancient times. It has been home to",
#             "completionReason": "LENGTH"
#         }
#     ]
# }

# %%
response = bedrock_runtime.invoke_model(**kwargs)
response_body = json.loads(response.get('body').read())

generation = response_body['results'][0]['outputText']
print(generation)
# Out:
# India is a country in South Asia officially known as the Republic of India. The country is officially a union of states, with the national capital in New Delhi for administrative purposes. India is the seventh-largest country by area, the second-most populous country, and the most populous democracy in the world.
#
# India is in the vicinity of the Himalayan mountains in the north, the Indian Ocean on the south, the Arabian Sea on the southwest and the Bay of Bengal on the southeast

# %%
print(json.dumps(response_body, indent=4))
# Out:
# {
#     "inputTextTokenCount": 6,
#     "results": [
#         {
#             "tokenCount": 100,
#             "outputText": "\nIndia is a country in South Asia officially known as the Republic of India. The country is officially a union of states, with the national capital in New Delhi for administrative purposes. India is the seventh-largest country by area, the second-most populous country, and the most populous democracy in the world.\n\nIndia is in the vicinity of the Himalayan mountains in the north, the Indian Ocean on the south, the Arabian Sea on the southwest and the Bay of Bengal on the southeast",
#             "completionReason": "LENGTH"
#         }
#     ]
# }

# %%
# Working with other type of data

# %%
from IPython.display import Audio

# %%
audio = Audio(filename="/Users/jsingh/Downloads/dailylife011.mp3")
display(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
with open('/Users/jsingh/Downloads/transcript.txt', "r") as file:
    dialogue_text = file.read()

# %%
print(dialogue_text)
# Out:
# My laptop is so slow. Buy a new one. I would, if I had the money.
#
# Why is it so slow? That's a good question. Did you take it to a computer shop? I would, if I had the money. Well, I guess you have to live with it.
#
# Sometimes I want to throw it out the window. You don't want to do that. Why not? You might hit someone in the head.

# %%
prompt = f"""The text between the <transcript> XML tags is a transcript of a conversation. 
Write a short summary of the conversation.

<transcript>
{dialogue_text}
</transcript>

Here is a summary of the conversation in the transcript:"""

# %%
print(prompt)
# Out:
# The text between the <transcript> XML tags is a transcript of a conversation.
# Write a short summary of the conversation.
#
# <transcript>
# My laptop is so slow. Buy a new one. I would, if I had the money.
#
# Why is it so slow? That's a good question. Did you take it to a computer shop? I would, if I had the money. Well, I guess you have to live with it.
#
# Sometimes I want to throw it out the window. You don't want to do that. Why not? You might hit someone in the head.
#
# </transcript>
#
# Here is a summary of the conversation in the transcript:

# %%
kwargs = {
    "modelId": "amazon.titan-text-express-v1",
    "contentType": "application/json",
    "accept": "*/*",
    "body": json.dumps(
        {
            "inputText": prompt,
            "textGenerationConfig": {
                "maxTokenCount": 512,
                "temperature": 0,
                "topP": 0.9
            }
        }
    )
}

# %%
response = bedrock_runtime.invoke_model(**kwargs)

# %%
response_body = json.loads(response.get('body').read())
generation = response_body['results'][0]['outputText']

# %%
print(generation)
# Out:
# Two people are discussing the slow speed of one of their laptops. One person suggests buying a new one, but the other person does not have the money. They discuss the possibility of taking the laptop to a computer shop, but the first person is hesitant due to the potential risk of hitting someone in the head.
